# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
trees = pd.read_csv('trees.csv')
trees.drop(columns=["OBJECTID"], inplace=True)
trees.drop(columns=["TYPE"], inplace=True)
trees
# Out:
#                 X          Y
# 0      -71.057663  42.354867
# 1      -71.057701  42.354878
# 2      -71.057797  42.354785
# 3      -71.056293  42.354740
# 4      -71.056308  42.354822
# ...           ...        ...
# 201840 -71.043263  42.370787
# 201841 -71.043513  42.370828
# 201842 -71.043586  42.370871
# 201843 -71.061997  42.371384
# 201844 -71.060025  42.371382
#
# [201845 rows x 2 columns]

# %%
type(trees)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(dpi=100)
plt.scatter(trees.X, trees.Y, marker='.', s=2, color='green', label="Trees")
plt.xlabel('This is the i-axis')
plt.ylabel('This is the j-ais')
plt.title("Trees in Boston")
plt.show()

# %%
gps_array = np.zeros((1000, 1000), dtype=int)

# %%
# for index, row in trees.iterrows():
    # print(row['X'], row['Y'])

# %% [markdown]
# ## Next Steps
# Write some math to split 0.2 up a thousand ways on the y-axis and 0.3 up a thousand ways on the x-axis, then just take each value and do the calculations to map it to the correct x and y indices. Easy!
