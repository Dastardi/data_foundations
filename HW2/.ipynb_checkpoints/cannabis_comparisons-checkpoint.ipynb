# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
con = sqlite3.connect('HW2.db')

# %%
query = "select Application_Status, x, y from cannabis where Application_Status != 'Withdrawn'"
cannabis = pd.read_sql_query(query, con)
cannabis
# Out:
#                            Application_Status                  x  \
# 0   Approved BCB - Executed HCA - Pending CCC  -71.0711305920434
# 1                         Open for Operations   -71.114390400915
# 2                          Open for operation   -71.114390400915
# 3                         Open for Operations  -71.0614305945262
# 4                      Conditionally approved   -71.170382999469
# ..                                        ...                ...
# 58                                   Approved  -71.0795305996831
# 59  Approved BCB - Executed HCA - Pending CCC  -71.1280406120948
# 60                                   Approved  -71.0540713083717
# 61                                   Approved  -71.0840705963286
# 62                                   Approved  -71.0417805813241
#
#                    y
# 0   42.3038486640959
# 1   42.2985766206975
# 2   42.2985766206975
# 3    42.364668674379
# 4   42.2683097088496
# ..               ...
# 58  42.3821386766087
# ...

# %%
crime_22 = pd.read_csv('boston_crime_2022.csv', low_memory=False)
crime_22 = crime_22[(crime_22['Lat'] >= 42.2) & (crime_22['Lat'] <= 42.4)]
crime_22 = crime_22[(crime_22['Long'] >= -71.2) & (crime_22['Long'] <= -71)]
crime_22
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           222076257           619                 NaN
# 1           222053099          2670                 NaN
# 2           222039411          3201                 NaN
# 3           222011090          3201                 NaN
# 4           222062685          3201                 NaN
# ...               ...           ...                 ...
# 73846       222101107          3111                 NaN
# 73847       232000091          1402                 NaN
# 73848       232000002          3831                 NaN
# 73849       232000140           619                 NaN
# 73851       232000052          3114                 NaN
#
#                          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                         LARCENY ALL OTHERS       D4            167
# 1            HARASSMENT/ CRIMINAL HARASSMENT       A7
# 2                   PROPERTY - LOST/ MISSING      D14            778
# ...

# %%
crime_loc = [Point(xy) for xy in zip(crime_22['Long'], crime_22['Lat'])]
crime_gdf = gpd.GeoDataFrame(crime_22, geometry=crime_loc)
crime_gdf
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           222076257           619                 NaN
# 1           222053099          2670                 NaN
# 2           222039411          3201                 NaN
# 3           222011090          3201                 NaN
# 4           222062685          3201                 NaN
# ...               ...           ...                 ...
# 73846       222101107          3111                 NaN
# 73847       232000091          1402                 NaN
# 73848       232000002          3831                 NaN
# 73849       232000140           619                 NaN
# 73851       232000052          3114                 NaN
#
#                          OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                         LARCENY ALL OTHERS       D4            167
# 1            HARASSMENT/ CRIMINAL HARASSMENT       A7
# 2                   PROPERTY - LOST/ MISSING      D14            778
# ...

# %%
cannabis_loc = [Point(xy) for xy in zip(cannabis['x'], cannabis['y'])]
cannabis_gdf = gpd.GeoDataFrame(cannabis, geometry=cannabis_loc)
cannabis_gdf
# Out:
#                            Application_Status                  x  \
# 0   Approved BCB - Executed HCA - Pending CCC  -71.0711305920434
# 1                         Open for Operations   -71.114390400915
# 2                          Open for operation   -71.114390400915
# 3                         Open for Operations  -71.0614305945262
# 4                      Conditionally approved   -71.170382999469
# ..                                        ...                ...
# 58                                   Approved  -71.0795305996831
# 59  Approved BCB - Executed HCA - Pending CCC  -71.1280406120948
# 60                                   Approved  -71.0540713083717
# 61                                   Approved  -71.0840705963286
# 62                                   Approved  -71.0417805813241
#
#                    y                    geometry
# 0   42.3038486640959  POINT (-71.07113 42.30385)
# 1   42.2985766206975  POINT (-71.11439 42.29858)
# ...

# %%
cannabis_buffers = cannabis_gdf.geometry.buffer(0.5)
cannabis_gdf
# Out:
#                            Application_Status                  x  \
# 0   Approved BCB - Executed HCA - Pending CCC  -71.0711305920434
# 1                         Open for Operations   -71.114390400915
# 2                          Open for operation   -71.114390400915
# 3                         Open for Operations  -71.0614305945262
# 4                      Conditionally approved   -71.170382999469
# ..                                        ...                ...
# 58                                   Approved  -71.0795305996831
# 59  Approved BCB - Executed HCA - Pending CCC  -71.1280406120948
# 60                                   Approved  -71.0540713083717
# 61                                   Approved  -71.0840705963286
# 62                                   Approved  -71.0417805813241
#
#                    y                    geometry
# 0   42.3038486640959  POINT (-71.07113 42.30385)
# 1   42.2985766206975  POINT (-71.11439 42.29858)
# ...
