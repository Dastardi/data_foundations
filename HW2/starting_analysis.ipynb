# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_18 = pd.read_csv('boston_crime_2018.csv')

# %%
crime_20 = pd.read_csv('boston_crime_2020.csv', low_memory=False)

# %%
crime_22 = pd.read_csv('boston_crime_2022.csv', low_memory=False)

# %%
cannabis = pd.read_csv('boston_cannabis_registry.csv')

# %%
wifi = pd.read_csv('boston_wifi.csv')

# %%
crime_18
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0          I192074715          2629            Harassment
# 1          I192068538          1107                 Fraud
# 2          I192005657          2610                 Other
# 3          I192075335          3208         Property Lost
# 4          I192013179           619               Larceny
# ...               ...           ...                   ...
# 98883      I182105272          3006    Medical Assistance
# 98884      I192000256          1402             Vandalism
# 98885      I192000003          3006    Medical Assistance
# 98886      I192000002          3114  Investigate Property
# 98887      I192000425          1402             Vandalism
#
#                  OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                         HARASSMENT       B2            278      NaN
# 1              FRAUD - IMPERSONATION      D14            794      NaN
# ...

# %%
crime_18.drop(['OFFENSE_CODE', 'OFFENSE_CODE_GROUP', 'DISTRICT', 'REPORTING_AREA', "OCCURRED_ON_DATE", 'UCR_PART', 'STREET'], axis=1)
crime_18
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0          I192074715          2629            Harassment
# 1          I192068538          1107                 Fraud
# 2          I192005657          2610                 Other
# 3          I192075335          3208         Property Lost
# 4          I192013179           619               Larceny
# ...               ...           ...                   ...
# 98883      I182105272          3006    Medical Assistance
# 98884      I192000256          1402             Vandalism
# 98885      I192000003          3006    Medical Assistance
# 98886      I192000002          3114  Investigate Property
# 98887      I192000425          1402             Vandalism
#
#                  OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                         HARASSMENT       B2            278      NaN
# 1              FRAUD - IMPERSONATION      D14            794      NaN
# ...

# %%
plt.figure(dpi=100)
plt.scatter(crime_18.Long, crime_18.Lat, marker='.', s=0.1, label="Crimes")
plt.xlabel('This is the j-axis, longitude')
plt.ylabel('This is the i-ais, latitude')
plt.title("Crimes in Boston")
plt.show()

# %%
crime_20
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0           212012996          1102                 NaN
# 1           212008096          1107                 NaN
# 2           202000034          3006                 NaN
# 3           202007210          1001                 NaN
# 4           202000355           617                 NaN
# ...               ...           ...                 ...
# 70889       202095668          3802                 NaN
# 70890       202095647          1402                 NaN
# 70891       212000339           801                 NaN
# 70892       212000004          3115                 NaN
# 70893       212000003          3114                 NaN
#
#                    OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  SHOOTING  \
# 0      FRAUD - FALSE PRETENSE / SCHEME       B2            259         0
# 1                FRAUD - IMPERSONATION       A1            118         0
# ...

# %%
plt.figure(dpi=100)
plt.scatter(crime_20.Long, crime_20.Lat, marker='.', label="Crimes")
plt.xlabel('This is the j-axis, longitude')
plt.ylabel('This is the i-ais, latitude')
plt.title("Crimes in Boston")
plt.show()

# %%
plt.figure(dpi=100)
plt.scatter(crime_22.Long, crime_22.Lat, marker='.', s=1, label="Crimes")
plt.xlabel('This is the j-axis, longitude')
plt.ylabel('This is the i-ais, latitude')
plt.title("Crimes in Boston")
plt.show()
